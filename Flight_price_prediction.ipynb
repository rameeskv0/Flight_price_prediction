# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_excel("C:/Users/0rame/Desktop/ML_tutorials/EDA/Datas/flight_Train_set.xlsx")

# %%
train
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
test = pd.read_excel("C:/Users/0rame/Desktop/ML_tutorials/EDA/Datas/flight_Test_set.xlsx")

# %%
test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
df = pd.concat([train,test],ignore_index=True)

# %%
df
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 13349          Air India       6/06/2019   Kolkata    Banglore
# 13350             IndiGo      27/03/2019   Kolkata    Banglore
# 13351        Jet Airways       6/03/2019     Delhi      Cochin
# 13352          Air India       6/03/2019     Delhi      Cochin
# 13353  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# ...

# %% [markdown]
# countplot for count

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Airline')
plt.title('Count of Airlines')
plt.xlabel('Airline')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-labels for better visibility
plt.show()

# %%
plt.figure(figsize=(10,6))
print(train['Date_of_Journey'].value_counts())
sns.countplot(data=df,x = 'Date_of_Journey')
plt.title("Date_of_Journey Counts")
plt.xlabel("Date_of_Journey")
plt.ylabel("Counts")
plt.show()

# %%
sns.countplot(data=train,x="Source")
plt.title("Source count")
plt.xlabel("source")
plt.ylabel("Count")
plt.show()

# %%
sns.countplot(data=train,x='Destination')
plt.title("Destination count")
plt.xlabel("destination")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# scatter plot (for dependency finding)

# %%
plt.figure(figsize=[10,6])
plt.title('Comparison of Airline and Price')
sns.scatterplot(data=df, x='Airline', y='Price', hue='Price')
plt.xticks(rotation=45)  # Rotate x-labels for better visibility
plt.xlabel('Airline')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x="Destination",y="Price",hue="Price")
plt.title("comparison of destination and price")
plt.xlabel("Destination")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x="Route",y="Price",hue="Price")
plt.title("comparison of Route and price")
plt.xlabel("Route")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x="Duration",y="Price",hue="Price")
plt.title("comparison of Duration and price")
plt.xlabel("Duration")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ### OUTLIER DETETCTION

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df['Date_of_Journey'],orient='h')
plt.title("boxplot of Date_of_Journey")
plt.xlabel("Date_of_Journey")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df['Airline'],orient='h')
plt.title("boxplot of airline")
plt.xlabel("Airline")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df['Additional_Info'],orient='h')
plt.title("boxplot of Additional_Info")
plt.xlabel("Additional_Info")
plt.show()

# %% [markdown]
# ### CORRELATION AND HEATMAP

# %%
corr = df.corr()

# %%
plt.figure(figsize=(30,15))
sns.heatmap(cor,annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")

# %%
plt.figure(figsize=(22,7))
cor['Price'].sort_values(ascending=False).drop(['Price']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# ### Distribution Plots

# %%
from scipy.stats import norm
plt.figure(figsize=(10,6))
sns.distplot(train['Airline'],fit=norm)

# %%
from scipy.stats import norm
plt.figure(figsize=(10,6))
sns.distplot(train['Arrival_Time'],fit=norm)

# %%
from scipy.stats import norm
plt.figure(figsize=(10,6))
sns.distplot(train['Price'],fit=norm)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# Date_of_Journey is in date format

# %%
df['Month'] = df['Date_of_Journey'].str.split('/').str[1]
df['Day'] = df['Date_of_Journey'].str.split('/').str[0]
df['Year'] = df['Date_of_Journey'].str.split('/').str[2]

# %% [markdown]
# we have splitted Date_of_journey into new 3 table , but its type will be string,so we need to convert it to integer

# %%
df['Day'] = df['Day'].astype('int')
df['Month'] = df['Month'].astype('int')
df['Year'] = df['Year'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Month            13354 non-null  int32
#  12  Day              13354 non-null  int32
#  13  Year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(10)
# memory usage: 1.3+ MB

# %% [markdown]
# now will drop Date_of_Journey column

# %%
df.drop(['Date_of_Journey'],inplace=True,axis=1)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price  Month  Day  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0      3   24
# 1         13:15   7h 25m     2 stops         No info   7662.0      5    1
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0      6    9
# 3         23:30   5h 25m      1 stop         No info   6218.0      5   12
# 4         21:35   4h 45m      1 stop         No info  13302.0      3    1
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %% [markdown]
# now in column Arrival time can also see the Date in there.no need of date there

# %%
df['Arrival_Time'] = df['Arrival_Time'].str.split(' ').str[0]

# %% [markdown]
# now can see in Arrival_Time only time is there

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Month  Day  Year
# 0        01:10   2h 50m    non-stop         No info   3897.0      3   24  2019
# 1        13:15   7h 25m     2 stops         No info   7662.0      5    1  2019
# 2        04:25      19h     2 stops         No info  13882.0      6    9  2019
# 3        23:30   5h 25m      1 stop         No info   6218.0      5   12  2019
# 4        21:35   4h 45m      1 stop         No info  13302.0      3    1  2019

# %%
df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Month                 0
# Day                   0
# Year                  0
# dtype: int64

# %% [markdown]
# can see Total_Stops and Route contains 1 null value each,ignore null values in Price bcs we created df concating train data with test data.Test data will not contain Price column.therefore it shows that much null values

# %% [markdown]
# still we need to split Arrival time into new col as Arrival _hour anf Arrival_Minute

# %%
df['Arrival_Hour'] = df['Arrival_Time'].str.split(':').str[0]
df['Arrival_Minute'] = df['Arrival_Time'].str.split(':').str[1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Month            13354 non-null  int32
#  11  Day              13354 non-null  int32
#  12  Year             13354 non-null  int32
#  13  Arrival_Hour     13354 non-null  object
#  14  Arrival_Minute   13354 non-null  object
# dtypes: float64(1), int32(3), object(11)
# memory usage: 1.4+ MB

# %% [markdown]
# can see Arrival_Hour and Arrival_Minute are in object ,now need to convert there type into integer
# and drop Arrival_Time column

# %%
df['Arrival_Hour'] = df['Arrival_Hour'].astype('int')
df['Arrival_Minute'] = df['Arrival_Minute'].astype('int')

# %%
df.drop('Arrival_Time',inplace=True,axis=1)

# %% [markdown]
# do the same for Departure_Time also

# %%
df['Dep_Hour'] = df['Dep_Time'].str.split(':').str[0]
df['Dep_Minute'] = df['Dep_Time'].str.split(':').str[1]

# %%
df['Dep_Hour'] = df['Dep_Hour'].astype('int')
df['Dep_Minute'] = df['Dep_Minute'].astype('int')

# %%
df.drop('Dep_Time',inplace=True,axis=1)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info    Price  Month  Day  Year  Arrival_Hour  \
# 0    non-stop         No info   3897.0      3   24  2019             1
# 1     2 stops         No info   7662.0      5    1  2019            13
# 2     2 stops         No info  13882.0      6    9  2019             4
# 3      1 stop         No info   6218.0      5   12  2019            23
# 4      1 stop         No info  13302.0      3    1  2019            21
#
#    Arrival_Minute  Dep_Hour  Dep_Minute
# 0              10        22          20
# 1              15         5          50
# ...

# %% [markdown]
# now we want take look an Route,Route having details of Stops in between the destination and source.you can either drop Total_stops or Route column.

# %%
df.drop('Route',inplace=True,axis=1)

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
df['Total_Stops'].isnull().sum()
# Out:
# 1

# %% [markdown]
# can see only 1 null value.assign other value with integer from 0 to 4

# %%
df['Total_Stops'] = df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1})

# %%
df[df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Duration  Total_Stops  \
# 9039  Air India  Delhi      Cochin   NaN  23h 40m          NaN
#
#      Additional_Info   Price  Month  Day  Year  Arrival_Hour  Arrival_Minute  \
# 9039         No info  7480.0      5    6  2019             9              25
#
#       Dep_Hour  Dep_Minute
# 9039         9          45

# %% [markdown]
# here Total_stops b/w Delhi anf Cochin is shown as nan,so we assign it as 1 stop flight

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info    Price  Month  Day  Year  Arrival_Hour  \
# 0          0.0         No info   3897.0      3   24  2019             1
# 1          2.0         No info   7662.0      5    1  2019            13
# 2          2.0         No info  13882.0      6    9  2019             4
# 3          1.0         No info   6218.0      5   12  2019            23
# 4          1.0         No info  13302.0      3    1  2019            21
#
#    Arrival_Minute  Dep_Hour  Dep_Minute
# 0              10        22          20
# ...

# %% [markdown]
# Duration feature needs to be converted into minutes completely by applying  mathematical formula

# %%
df['Duration_Hour'] = df['Duration'].str.split('h').str[0]

# %%
df[df['Duration_Hour'] == '5m']
# Out:
#          Airline  Source Destination                  Route Duration  \
# 6474   Air India  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD       5m
# 13343  Air India  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD       5m
#
#        Total_Stops Additional_Info    Price  Month  Day  Year  Arrival_Hour  \
# 6474           2.0         No info  17327.0      3    6  2019            16
# 13343          2.0         No info      NaN      3   12  2019            16
#
#        Arrival_Minute  Dep_Hour  Dep_Minute Duration_Hour
# 6474               55        16          50            5m
# 13343              55        16          50            5m

# %% [markdown]
# here we can see there is also 5m value in Duration_hour,thats not possible,taking 5 only also cause issues ,
# therefore we need to drop this 2 rows

# %%
df.drop(6474,inplace=True,axis=0)
df.drop(13343,inplace=True,axis=0)

# %%
df[df['Duration_Hour'] == '5m']
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Route, Duration, Total_Stops, Additional_Info, Price, Month, Day, Year, Arrival_Hour, Arrival_Minute, Dep_Hour, Dep_Minute, Duration_Hour]
# Index: []

# %% [markdown]
# can see now there is only hour values,so we can convert it into int

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info    Price  Month  Day  Year  Arrival_Hour  \
# 0          0.0         No info   3897.0      3   24  2019             1
# 1          2.0         No info   7662.0      5    1  2019            13
# 2          2.0         No info  13882.0      6    9  2019             4
# 3          1.0         No info   6218.0      5   12  2019            23
# 4          1.0         No info  13302.0      3    1  2019            21
#
#    Arrival_Minute  Dep_Hour  Dep_Minute Duration_Hour Duration_Minute
# ...

# %%
df['Duration'].values
# Out:
# array(['2h 50m', '7h 25m', '19h', ..., '6h 35m', '15h 15m', '14h 20m'],
#       dtype=object)

# %%
def duration_to_minutes(duration):
    if 'h' in duration and 'm' in duration:
        hours, minutes = duration.split(' ')
        hours = int(hours[:-1]) if hours[:-1] else 0
        minutes = int(minutes[:-1]) if minutes[:-1] else 0
    elif 'h' in duration:
        hours = int(duration.split('h')[0])
        minutes = 0
    elif 'm' in duration:
        hours = 0
        minutes = int(duration.split('m')[0])
    else:
        hours = 0
        minutes = 0
    return hours * 60 + minutes

# Apply the function to create a new column 'Duration_minutes'
df['Duration_minutes'] = df['Duration'].apply(duration_to_minutes)

# %%
df.drop(['Duration','Duration_Hour','Duration_Minute'],inplace=True,axis=1)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL          0.0
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR          2.0
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK          2.0
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR          1.0
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL          1.0
#
#   Additional_Info    Price  Month  Day  Year  Arrival_Hour  Arrival_Minute  \
# 0         No info   3897.0      3   24  2019             1              10
# 1         No info   7662.0      5    1  2019            13              15
# 2         No info  13882.0      6    9  2019             4              25
# 3         No info   6218.0      5   12  2019            23              30
# 4         No info  13302.0      3    1  2019            21              35
#
#    Dep_Hour  Dep_Minute  Duration_minutes
# ...

# %% [markdown]
# converted the Duration column completly into minutes and add as a new column instead of splitting into Duration_Hour,Duration_minutes
# Also dropped the Duration column

# %% [markdown]
# now we deal with Airline column

# %%
df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df['Airline'] = encoder.fit_transform(df['Airline'])

# %% [markdown]
# do the same for othe text data column also

# %%
df['Source'] = encoder.fit_transform(df['Source'])
df['Destination'] = encoder.fit_transform(df['Destination'])
df['Additional_Info'] = encoder.fit_transform(df['Additional_Info'])

# %%
df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price  Month  \
# 0        3       0            5          0.0                8   3897.0      3
# 1        1       3            0          2.0                8   7662.0      5
# 2        4       2            1          2.0                8  13882.0      6
# 3        3       3            0          1.0                8   6218.0      5
# 4        3       0            5          1.0                8  13302.0      3
#
#    Day  Year  Arrival_Hour  Arrival_Minute  Dep_Hour  Dep_Minute  \
# 0   24  2019             1              10        22          20
# 1    1  2019            13              15         5          50
# 2    9  2019             4              25         9          25
# 3   12  2019            23              30        18           5
# 4    1  2019            21              35        16          50
#
#    Duration_minutes
# 0               170
# 1               445
# 2              1140
# ...

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df,x='Price')
plt.title("count of price")
plt.xlabel("price")
plt.ylabel("count")
plt.show()

# %% [markdown]
# checking null values

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Airline                0
# Source                 0
# Destination            0
# Total_Stops            1
# Additional_Info        0
# Price               2670
# Month                  0
# Day                    0
# Year                   0
# Arrival_Hour           0
# Arrival_Minute         0
# Dep_Hour               0
# Dep_Minute             0
# Duration_minutes       0
# dtype: int64

# %%
df['Total_Stops'] = df['Total_Stops'].fillna(df['Total_Stops'].mode()[0])

# %% [markdown]
# null value in the total stop is filled with mode value of the same column

# %%
df[df.duplicated()]
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info    Price  \
# 683          4       2            1          2.0                8  13376.0
# 1061         1       2            1          2.0                8  10231.0
# 1348         1       2            1          2.0                8  12392.0
# 1418         4       2            1          2.0                5  10368.0
# 1674         3       0            5          0.0                8   7303.0
# ...        ...     ...          ...          ...              ...      ...
# 13219        1       2            1          2.0                8      NaN
# 13236        4       2            1          2.0                8      NaN
# 13243        6       2            1          1.0                8      NaN
# 13265        1       3            0          2.0                8      NaN
# 13266        3       0            5          0.0                8      NaN
#
# ...

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# Count Plots

# %%
df['Airline'].value_counts()
# Out:
# Airline
# 4     4746
# 3     2564
# 1     2190
# 6     1543
# 8     1026
# 10     608
# 0      405
# 2      240
# 7       16
# 5        8
# 11       5
# 9        1
# Name: count, dtype: int64

# %%
df.skew()
# Out:
# Airline             0.720860
# Source             -0.424410
# Destination         1.248413
# Total_Stops         0.317982
# Additional_Info    -1.784512
# Price               1.813248
# Month              -0.391029
# Day                 0.134961
# Year                0.000000
# Arrival_Hour       -0.384413
# Arrival_Minute      0.111689
# Dep_Hour            0.109328
# Dep_Minute          0.159687
# Duration_minutes    0.867859
# dtype: float64

# %% [markdown]
# Here can see Additional_Info and Destination showing high skewness

# %% [markdown]
# ### Removing Skewness using sqrt

# %%
from scipy import sqrt

# %%
df['Destination'] = np.sqrt(df['Destination'])

# %%
df.skew()
# Out:
# Airline             0.720860
# Source             -0.424410
# Destination         0.021922
# Total_Stops         0.317982
# Additional_Info    -1.784512
# Price               1.813248
# Month              -0.391029
# Day                 0.134961
# Year                0.000000
# Arrival_Hour       -0.384413
# Arrival_Minute      0.111689
# Dep_Hour            0.109328
# Dep_Minute          0.159687
# Duration_minutes    0.867859
# dtype: float64

# %%
df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price  Month  \
# 0        3       0     2.236068          0.0                8   3897.0      3
# 1        1       3     0.000000          2.0                8   7662.0      5
# 2        4       2     1.000000          2.0                8  13882.0      6
# 3        3       3     0.000000          1.0                8   6218.0      5
# 4        3       0     2.236068          1.0                8  13302.0      3
#
#    Day  Year  Arrival_Hour  Arrival_Minute  Dep_Hour  Dep_Minute  \
# 0   24  2019             1              10        22          20
# 1    1  2019            13              15         5          50
# 2    9  2019             4              25         9          25
# 3   12  2019            23              30        18           5
# 4    1  2019            21              35        16          50
#
#    Duration_minutes
# 0               170
# 1               445
# 2              1140
# ...

# %% [markdown]
# we will drop Additional_Info

# %%
df.drop('Additional_Info',inplace=True,axis=1)

# %%
df = df[~df['Price'].isnull()]

# %%
df.shape
# Out:
# (10682, 13)

# %%
x = df.drop('Price',axis=1)
y = df['Price']

# %%
x.shape
y.shape
# Out:
# (10682,)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,random_state=42,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
xtrain = scaler.fit_transform(xtrain)
xtest =  scaler.fit_transform(xtest)

# %% [markdown]
# ### KNeighbor Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# ### HYPER PARAMETER TUNING FOR KNN

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={'n_neighbors':np.arange(2,10),
          'weights':['uniform','distance'],
          'algorithm':['auto','ball_tree','kd_tree','brute'],'leaf_size':[5,10,15]}

# %%
GCV=GridSearchCV(KNeighborsRegressor(),parameter,cv=5)

# %%
GCV.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [5, 10, 15],
#                          'n_neighbors': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'weights': ['uniform', 'distance']})

# %%
GCV.best_params_
# Out:
# {'algorithm': 'ball_tree',
#  'leaf_size': 15,
#  'n_neighbors': 4,
#  'weights': 'uniform'}

# %% [markdown]
# PASSING THIS BEST PARAMETER VALUES TO MODEL

# %%
Flight_model=KNeighborsRegressor(algorithm ='ball_tree', n_neighbors = 9, weights = 'distance',leaf_size = 15)

# %%
Flight_model.fit(xtrain,ytrain)
# Out:
# KNeighborsRegressor(algorithm='ball_tree', leaf_size=15, n_neighbors=9,
#                     weights='distance')

# %%
Finalpred=Flight_model.predict(xtest)

# %%
Finalr2score=r2_score(ytest,Finalpred)

# %%
print(Finalr2score)
# Out:
# 0.7405193382768954

# %%
with open(f"flight.pkl", 'wb') as file:
        pickle.dump(Flight_model,file)

# %%
import csv

# Sample user inputs
user_inputs = [
    {'Airline': 'IndiGo', 'Date_of_Journey': '24/03/2019', 'Source': 'Bangalore', 'Destination': 'New Delhi', 'Route': 'BLR → DEL', 'Dep_Time': '22:20', 'Arrival_Time': '01:10 22 Mar', 'Duration': '2h 50m', 'Total_Stops': 'non-stop', 'Additional_Info': 'No info'},
    {'Airline': 'Air India', 'Date_of_Journey': '01/05/2019', 'Source': 'Kolkata', 'Destination': 'Bangalore', 'Route': 'CCU → IXR → BBI → BLR', 'Dep_Time': '05:50', 'Arrival_Time': '13:15', 'Duration': '7h 25m', 'Total_Stops': '2 stops', 'Additional_Info': 'No info'},
    {'Airline': 'Jet Airways', 'Date_of_Journey': '09/06/2019', 'Source': 'Delhi', 'Destination': 'Cochin', 'Route': 'DEL → LKO → BOM → COK', 'Dep_Time': '09:25', 'Arrival_Time': '04:25 10 Jun', 'Duration': '19h', 'Total_Stops': '2 stops', 'Additional_Info': 'No info'}
]

# CSV file name

csv_file = 'user_inputs.csv'

# Writing user inputs to CSV with UTF-8 encoding
with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=user_inputs[0].keys())
    writer.writeheader()
    writer.writerows(user_inputs)

print(f"CSV file '{csv_file}' created successfully.")
# Out:
# CSV file 'user_inputs.csv' created successfully.

# %%
sample = pd.read_csv('user_inputs.csv')

# %%
sample
# Out:
#        Airline Date_of_Journey     Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Bangalore   New Delhi              BLR → DEL
# 1    Air India      01/05/2019    Kolkata   Bangalore  CCU → IXR → BBI → BLR
# 2  Jet Airways      09/06/2019      Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info
# 1    05:50         13:15   7h 25m     2 stops         No info
# 2    09:25  04:25 10 Jun      19h     2 stops         No info

# %%
sample.drop(['Additional_Info','Route'],inplace=True,axis=1)

# %%
sample['Airline'] = encoder.fit_transform(sample['Airline'])

# %%
sample['Source'] = encoder.fit_transform(sample['Source'])
sample['Destination'] = encoder.fit_transform(sample['Destination'])

# %%
sample[]
# Out:
#    Airline Date_of_Journey  Source  Destination Dep_Time  Arrival_Time  \
# 0        1      24/03/2019       0            2    22:20  01:10 22 Mar
# 1        0      01/05/2019       2            0    05:50         13:15
# 2        2      09/06/2019       1            1    09:25  04:25 10 Jun
#
#   Duration Total_Stops
# 0   2h 50m    non-stop
# 1   7h 25m     2 stops
# 2      19h     2 stops

# %%
sample['Month'] = sample['Date_of_Journey'].str.split('/').str[1]
sample['Day'] = sample['Date_of_Journey'].str.split('/').str[0]
sample['Year'] = sample['Date_of_Journey'].str.split('/').str[2]

# %%
sample['Day'] = sample['Day'].astype('int')
sample['Month'] = sample['Month'].astype('int')
sample['Year'] = sample['Year'].astype('int')

# %%
sample.drop('Date_of_Journey',inplace=True,axis=1)

# %%
sample
# Out:
#    Airline  Source  Destination Dep_Time  Arrival_Time Duration Total_Stops  \
# 0        1       0            2    22:20  01:10 22 Mar   2h 50m    non-stop
# 1        0       2            0    05:50         13:15   7h 25m     2 stops
# 2        2       1            1    09:25  04:25 10 Jun      19h     2 stops
#
#    Month  Day  Year
# 0      3   24  2019
# 1      5    1  2019
# 2      6    9  2019

# %%
sample['Arrival_Hour'] = sample['Arrival_Time'].str.split(':').str[0]
sample['Arrival_Minute'] = sample['Arrival_Time'].str.split(':').str[1]

# %%
sample
# Out:
#    Airline  Source  Destination Dep_Time  Arrival_Time Duration Total_Stops  \
# 0        1       0            2    22:20  01:10 22 Mar   2h 50m    non-stop
# 1        0       2            0    05:50         13:15   7h 25m     2 stops
# 2        2       1            1    09:25  04:25 10 Jun      19h     2 stops
#
#    Month  Day  Year  Arrival_Hour Arrival_Minute
# 0      3   24  2019             1      10 22 Mar
# 1      5    1  2019            13             15
# 2      6    9  2019             4      25 10 Jun

# %%
sample['Arrival_Time'] = sample['Arrival_Time'].str.split(' ').str[0]

# %%
sample['Arrival_Hour'] = sample['Arrival_Hour'].astype('int')
sample['Arrival_Minute'] = sample['Arrival_Minute'].astype('int')

# %%
sample
# Out:
#    Airline  Source  Destination Dep_Time Arrival_Time Duration Total_Stops  \
# 0        1       0            2    22:20        01:10   2h 50m    non-stop
# 1        0       2            0    05:50        13:15   7h 25m     2 stops
# 2        2       1            1    09:25        04:25      19h     2 stops
#
#    Month  Day  Year  Arrival_Hour  Arrival_Minute
# 0      3   24  2019             1              10
# 1      5    1  2019            13              15
# 2      6    9  2019             4              25

# %%
sample.drop('Arrival_Time',inplace=True,axis=1)

# %%
sample
# Out:
#    Airline  Source  Destination Dep_Time Duration Total_Stops  Month  Day  \
# 0        1       0            2    22:20   2h 50m    non-stop      3   24
# 1        0       2            0    05:50   7h 25m     2 stops      5    1
# 2        2       1            1    09:25      19h     2 stops      6    9
#
#    Year  Arrival_Hour  Arrival_Minute
# 0  2019             1              10
# 1  2019            13              15
# 2  2019             4              25

# %%
sample['Total_Stops'] = sample['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1})

# %%
sample
# Out:
#    Airline  Source  Destination Dep_Time Duration  Total_Stops  Month  Day  \
# 0        1       0            2    22:20   2h 50m            0      3   24
# 1        0       2            0    05:50   7h 25m            2      5    1
# 2        2       1            1    09:25      19h            2      6    9
#
#    Year  Arrival_Hour  Arrival_Minute
# 0  2019             1              10
# 1  2019            13              15
# 2  2019             4              25

# %%
def duration_to_minutes(duration):
    if 'h' in duration and 'm' in duration:
        hours, minutes = duration.split(' ')
        hours = int(hours[:-1]) if hours[:-1] else 0
        minutes = int(minutes[:-1]) if minutes[:-1] else 0
    elif 'h' in duration:
        hours = int(duration.split('h')[0])
        minutes = 0
    elif 'm' in duration:
        hours = 0
        minutes = int(duration.split('m')[0])
    else:
        hours = 0
        minutes = 0
    return hours * 60 + minutes

# Apply the function to create a new column 'Duration_minutes'
sample['Duration_minutes'] = sample['Duration'].apply(duration_to_minutes)

# %%
sample.drop('Duration',inplace=True,axis=1)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           3 non-null      int32
#  1   Source            3 non-null      int64
#  2   Destination       3 non-null      int64
#  3   Dep_Time          3 non-null      object
#  4   Total_Stops       3 non-null      int64
#  5   Month             3 non-null      int32
#  6   Day               3 non-null      int32
#  7   Year              3 non-null      int32
#  8   Arrival_Hour      3 non-null      int32
#  9   Arrival_Minute    3 non-null      int32
#  10  Duration_minutes  3 non-null      int64
# dtypes: int32(6), int64(4), object(1)
# memory usage: 324.0+ bytes

# %%
sample['Dep_Hour'] = sample['Dep_Time'].str.split(':').str[0]
sample['Dep_Minute'] = sample['Dep_Time'].str.split(':').str[1]

# %%
sample['Dep_Hour'] = sample['Dep_Hour'].astype('int')
sample['Dep_Minute'] = sample['Dep_Minute'].astype('int')

# %%
sample.drop('Dep_Time',inplace=True,axis=1)

# %%
sample
# Out:
#    Airline  Source  Destination  Total_Stops  Month  Day  Year  Arrival_Hour  \
# 0        1       0            2            0      3   24  2019             1
# 1        0       2            0            2      5    1  2019            13
# 2        2       1            1            2      6    9  2019             4
#
#    Arrival_Minute  Duration_minutes  Dep_Hour  Dep_Minute
# 0              10               170        22          20
# 1              15               445         5          50
# 2              25              1140         9          25

# %%
xtrain.shape
# Out:
# (7477, 12)

# %%
sample.shape
# Out:
# (3, 12)

# %%
sample_values = sample[:1].values

# %%
sample_values
# Out:
# array([[   1,    0,    2,    0,    3,   24, 2019,    1,   10,  170,   22,
#           20]], dtype=int64)
